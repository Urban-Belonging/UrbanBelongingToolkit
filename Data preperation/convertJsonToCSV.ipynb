# %% [markdown]
# ## Description
# This script will convert the raw JSON from the UrbanBelonging app to a CSV file containing aggregated results per photo.
# It depends on 3 different JSON files:
# - An export of the users, with their corresponding organisation values.
# - An export of the routes walked by the participants
# - An export of all the photos and corresponding annotations and reactions.
#
# If you only want to convert the export of all the photos, you have to remove the part of the main script where we map photos to a specific route. The user orginisation data is only used to create the unique code at the end of this notebook.

# %%
import csv
import json
from datetime import datetime

# %% [markdown]
# Retrieve users and demographic group from JSON for later use

# %%
users = {}

# %%
with open("Export_Users-1631800777087.json", "r", encoding='utf8') as read_userfiles:
    userlist = json.load(read_userfiles)
    for user in userlist['result']['users']:
        if 'demographicGroup' in user.keys():
            users[user['id']] = user['demographicGroup']
        else:
            users[user['id']] = None

# %% [markdown]
# Retrieve routes from JSON to match with photos datetimes later

# %%
routeList = []
with open('Export_Event_Walks-1632149465145_final.json', newline='', encoding='utf8') as routefile:
    routes = json.load(routefile)
    for route in routes['result']['walks']:
        routeList.append({'routeid': route['id'], 'start_time':route['startedAt'], 'end_time': route['endedAt'], 'userId':route['createdBy']})

# %% [markdown]
# Open and process event file contain all photos

# %%
with open("../Export_Event-1633420386924.json", "r", encoding='utf-8') as read_file:
    data = json.load(read_file)
    dataList = []
    
    for photo in data['result']['photos']:
        
        #Setup dictionaries for counting annotations and reactions. 
        slider_categories= {
                'slider_pos': 0,
                'slider_amb': 0,
                'slider_neg': 0 }
        
        annotation_categories = {
            "Architecture": 0,
            "Urban Environment": 0,
            "Objects": 0,
            "Signs & symbols": 0,
            "Urban Nature": 0,
            "Wind & Weather": 0,
            "Culture": 0,
            "Consumption": 0,
            "People /community": 0,
            "Infrastructure": 0,
            "Memories & associations": 0,
            "Atmosphere": 0,
            "Don't know": 0,
            "Other": 0,
            "OtherText": ''}
    
        reaction_categories = {
            "Architecture": 0,
            "Urban Environment": 0,
            "Objects": 0,
            "Signs & symbols": 0,
            "Urban Nature": 0,
            "Wind & Weather": 0,
            "Culture": 0,
            "Consumption": 0,
            "People /community": 0,
            "Infrastructure": 0,
            "Memories & associations": 0,
            "Atmosphere": 0,
            "Don't know": 0,
            "Other": 0,
            "OtherText": ''}
        
        pos_reaction_categories = {
            "Architecture": 0,
            "Urban Environment": 0,
            "Objects": 0,
            "Signs & symbols": 0,
            "Urban Nature": 0,
            "Wind & Weather": 0,
            "Culture": 0,
            "Consumption": 0,
            "People /community": 0,
            "Infrastructure": 0,
            "Memories & associations": 0,
            "Atmosphere": 0,
            "Don't know": 0,
            "Other": 0,
            "OtherText": ''}
         
        neg_reaction_categories = {
            "Architecture": 0,
            "Urban Environment": 0,
            "Objects": 0,
            "Signs & symbols": 0,
            "Urban Nature": 0,
            "Wind & Weather": 0,
            "Culture": 0,
            "Consumption": 0,
            "People /community": 0,
            "Infrastructure": 0,
            "Memories & associations": 0,
            "Atmosphere": 0,
            "Don't know": 0,
            "Other": 0,
            "OtherText": ''}
        
        #Create empty dict for each photo and start filling it with relevant info from raw JSON
        photo_data = {}
        photo_data['photo_url_thumb'] = photo['thumbnails'][2]['url']
        photo_data['photo_url_original'] = photo['imageUrl']
        photo_data['userId'] = photo['createdBy']  
        photo_data['photoId'] = photo['id']
        photo_data['createdAt'] = photo['createdAt']
        # !! Remove if no User Data !!
        if users:
            photo_data['userOrg'] = users[photo['createdBy']]
        else:
            photo_data['userOrg'] = None
        
        # Try to map photos to a specific route if photo is taken in the route timeframe by the same user. 
        for route in routeList:
            if route['userId'] == photo['createdBy']:
                startTime = datetime.strptime(route['start_time'], '%Y-%m-%dT%H:%M:%S.%fZ')
                endTime = datetime.strptime(route['end_time'], '%Y-%m-%dT%H:%M:%S.%fZ')
                photoTime = datetime.strptime(photo['createdAt'], '%Y-%m-%dT%H:%M:%S.%fZ')
                if photoTime > startTime and photoTime < endTime:
                    photo_data['routeId'] = route['routeid']
        if 'routeId'  not in photo_data:
            photo_data['routeId'] = None
            
        # sometimes location data is not properly attached and is missing.  
        if photo['locationData'] is not None:
            photo_data['latitude'] = photo['locationData']['latitude']
            photo_data['longitude'] = photo['locationData']['longitude']
        else:
            photo_data['latitude'] = None
            photo_data['longitude'] = None
        
        # Check which annotations are given to it by the user taking the photo. Add texts from 'Other' variable in seperate field.
        if len(photo['annotationAnswers']) != 0:
           
            # Store data from slider
            photo_data['slider_answer'] = photo['annotationAnswers'][0]['sliderAnswer']
            
            # Handle one or more annotation labels
            mp_answer = photo['annotationAnswers'][1]['multipleChoiceAnswer']
            photo_data['annot_answerString'] = ', '.join(mp_answer)
            for answer in mp_answer:
                if answer in annotation_categories:
                    annotation_categories[answer] += 1
                elif answer not in annotation_categories:
                    annotation_categories['Other'] += 1
                    if len(annotation_categories['OtherText']) == 0:
                        annotation_categories['OtherText'] = answer
                    else:
                        annotation_categories['OtherText'] = annotation_categories['OtherText']+ '|'+answer
                    
        else:
            photo_data['slider_answer'] = None
        annotation_categories = {'annot_'+k: v for k, v in annotation_categories.items()}

        # REACTIONS
        sliderTotal = 0
        annotationCount = len(photo['reactions'])
        photo_data['reaction_count'] = annotationCount
        for reaction in photo['reactions']:
            # To better understand which labels are given based in a positive or negative context,
            # based on the slider value, seperate counts are being done:
            #  - Counts of labels based on negative sentiment (slider value => 4)
            #  - Counts of labels based on positive sentiment (slider value <= 2)
            #  - Counts of labels regardsless of sentiment
            
            answers = reaction['answers'][1]['multipleChoiceAnswer']
            sliderAnswer = reaction['answers'][0]['sliderAnswer']
            
            # Positive
            if sliderAnswer >= 4:
                slider_categories['slider_pos'] += 1
                for answer in answers:
                    if answer in reaction_categories:
                        pos_reaction_categories[answer] += 1
                    else:
                        pos_reaction_categories['Other'] += 1
                        if len(pos_reaction_categories['OtherText']) == 0:
                            pos_reaction_categories['OtherText'] = answer
                        else:
                            pos_reaction_categories['OtherText'] = pos_reaction_categories['OtherText']+ '|'+answer
            # Negative
            elif sliderAnswer <= 2:
                slider_categories['slider_neg'] += 1
                for answer in answers:
                    if answer in reaction_categories:
                        neg_reaction_categories[answer] += 1
                    else:
                        neg_reaction_categories['Other'] += 1
                        if len(neg_reaction_categories['OtherText']) == 0:
                            neg_reaction_categories['OtherText'] = answer
                        else:
                            neg_reaction_categories['OtherText'] = neg_reaction_categories['OtherText']+ '|'+answer
            elif sliderAnswer == 3:
                slider_categories['slider_amb'] += 1
            
            sliderTotal += sliderAnswer
            
            # No sentiment (all reactions)
            for answer in answers:
                if answer in reaction_categories:
                    reaction_categories[answer] += 1
                else:
                    print('cant find'+answer)
                    reaction_categories['Other'] += 1
                    if len(reaction_categories['OtherText']) == 0:
                        reaction_categories['OtherText'] = answer
                    else:
                        reaction_categories['OtherText'] = reaction_categories['OtherText']+ '|'+answer
       
        #change the future columns names so we know which category we are looking at.
        reaction_categories = {'react'+k: v for k, v in reaction_categories.items()}
        pos_reaction_categories = {'pos_react'+k: v for k, v in pos_reaction_categories.items()}
        neg_reaction_categories = {'neg_react'+k: v for k, v in neg_reaction_categories.items()}
        
        #calculate the average slider values from all reactions
        if annotationCount != 0:
            sliderAverage = round(sliderTotal/annotationCount, 1)
        else:
            sliderAverage = 0
        photo_data['sliderAverage'] = sliderAverage
        
        # Check whether there is a large difference between the input from the user who created the photo compared to the
        # average of reactions. 
        if annotationCount != 0:
            if photo_data['slider_answer'] != None:
                photo_data['sliderDiff'] = (photo_data['slider_answer']-sliderAverage)*-1
            else:
                photo_data['sliderDiff'] = None
        else:
            photo_data['sliderDiff'] = None
        if photo_data['sliderDiff'] != None:
            if photo_data['sliderDiff'] >=2 or photo_data['sliderDiff'] <= -2:
                photo_data['largeSliderGap'] = True
            else:
                photo_data['largeSliderGap'] = False
        else:
            photo_data['largeSliderGap'] = False
            
        #combine all aggregated data in one dictionary and add to datalist    
        fullDict = {**photo_data, **slider_categories, **annotation_categories, **reaction_categories, **pos_reaction_categories, **neg_reaction_categories}
        dataList.append(fullDict)
# Out:
# cant findMin barndom
# cant findObstrucle
# cant findInclusion
# cant findObstacle
# cant findLiv&Død
# cant findFredagsbar
# cant findHåbefulde studerende
# cant findA smile on your lip
# cant findSkæbner
# cant findNeutral
# cant findNeutral
# cant findNeutral
# cant findNeutral
# cant findNeutral
# cant findKunst
# cant findSkæbner
# cant findHistorier
# cant findHumours
# cant findKunst
# cant findGammelt er blevet til nyt
# cant findSamlingspunkt
# cant findOpofrelse
# cant findKrig og død
# cant findSamarbejde
# cant findFamilier i sorg og glæde
# cant findRespect
# cant findKunst
# cant findGod tur til kørestolen
# cant findFremtidens ghetto
# cant findByggesjusk
# cant findEn bænk til at slappe af på
# cant findOp af bakke
# cant findUtydeligr
# cant findByggesjusk
# cant findGrådighed
# cant findTømmermandsarkitektur
# cant findParkering lag på lag
# cant findTransportmiddel
# cant findGlæde og sorg
# cant findEufori
# cant findNationalsymbol
# cant findSjæl
# cant findHistorier
# cant findSammenhold
# cant findIkonesk
# cant findHensyn
# cant findOpsyn
# cant findHjælpsomhed
# cant findStress
# cant findTidstyrani
# cant findSammenhold
# cant findNeutral
# cant findSame as
# cant findOplevelser
# cant findSame as
# cant findKunst
# cant findHistorier
# cant findSkæbner
# cant findNeutral
# cant findEn lige linje
# cant findNeutral
# cant findDårlige toiletforhold for handicappede
# cant findStilhed
# cant findRespect
# cant findRespect
# cant findEn doven hundeejer
# cant findEgoist
# cant findTravlhed
# cant findKaos fredag eftermiddag
# cant findKaos fredag eftermiddag
# cant findSame as
# cant findInclusion
# cant findKunst
# cant findSame as
# cant findHader selfies og joints
# cant findShips;)
# cant findSafety measures
# cant findSame as
# cant findBirds
# cant findHvem beskytter hvem
# cant findGavlmalerier
# cant findKunst
# cant findSammenhold
# cant findLeg
# cant findSammenhold
# cant findHistorier
# cant findSkæbner
# cant findLights
# cant findHistorier
# cant findUd&Se med DSB
# cant findSkæbner
# cant findMagtens højborg
# cant findDemokrati
# cant findMagtelite
# cant findLys
# cant findSkæbner
# cant findSupercykelsti
# cant findHvor stillede jeg nu min cykel?
# cant findKunst
# cant findSamtalebænk
# cant findKunst
# cant findBillige ungdomsboliger
# cant findMange mennesker på lidt plads
# cant findUdsigt
# cant findKunst
# cant findLiv og Død
# cant findSammenhold
# cant findHistorie
# cant findSkæbner
# cant findLeg
# cant findFantasi
# cant findYoga for mødre
# cant findLeg
# cant findFantasi
# cant findSidste hilsen
# cant findSame as
# cant findSame as
# cant findNy type gavlmaleri
# cant findGode forestillinger
# cant findLæring
# cant findOplevelser
# cant findForhindringsløb for kørestole og blinde
# cant findHistorie
# cant findSkæbner
# cant findOpofrelse
# cant findLiv og Død
# cant findSammenhold
# cant findKamp
# cant findBeslutninger
# cant findKonger og Dronninger
# cant findSvær adgang for fodgængere
# cant findTro
# cant findSammenhold
# cant findInduktrinering
# cant findAmagerbakke der aldrig skullet have været bygget
# cant findAmagerbakke en politikers eftermæle
# cant findMotion
# cant find1. maj
# cant findArbejderbevægelsen
# cant findTro
# cant findSimphatic people;)
# cant findNem måde at komme fra A-B
# cant findSamtalebænk
# cant findIkon
# cant findEn elevator der altid går i stykker
# cant findNye madopskrifter
# cant findDufte
# cant findEn verden at vælge imellem
# cant findDer er viste en hæk der trænger til at blive klippet
# cant findEt skjult hjørne
# cant findAltid en cykel du kan låne🤔
# cant findBevarelse
# cant findSupercykelstier
# cant findHistorie
# cant findNy badebro
# cant findIgen trapper!
# cant findPolitik
# cant findUndertrykkelse
# cant findDiktatur
# cant findNaturbevarelse
# cant findSamlingspunkt
# cant findGræsrødder
# cant findTorturinstrumenter
# cant findDårlig samvittighed
# cant findMotion
# cant findAfslapning
# cant find;)
# cant findSamlingspunkt
# cant findLeg
# cant findGrim opbevaring
# cant findKoldt
# cant findSamlingspunkt
# cant findMad
# cant findMin barndom
# cant findMiljø
# cant findNogen der har glemt at aflevere en lånt cykel
# cant findGræsrødder
# cant findAmused
# cant findLeg
# cant findAnimal
# cant findRedningsvej
# cant findMin barndom
# cant findMin barndom
# cant findStien er for kort!
# cant findForbudt parkering for cykler
# cant findIngen adgang for kørestole
# cant findMe and me alone
# cant findMors Ferrari
# cant findKunst
# cant findKunst
# cant findTrænger til en kærlig hånd
# cant findLygtepælen fryser
# cant findLeg
# cant findKunst
# cant findMastodont
# cant findUtydeligt
# cant findHistorie
# cant findWaste of my time !
# cant findUtydeligt
# cant findForvirrende
# cant findMor passer på dig
# cant findcars
# cant findHistorie
# cant findcars
# cant findPas på det ikke falder ned om ørerne på dig
# cant findByggesjusk
# cant findDyre boliger
# cant findEkskluderende
# cant findElite
# cant findSkal alle have en altan nu
# cant findInclusive
# cant findConcrete
# cant findAnimals
# cant findAnimals
# cant findSamtalebænk
# cant findAnimal:)
# cant findMount Everest for kørestole
# cant findLiv/død
# cant findØkologi
# cant findconstruction
# cant finddust
# cant findconstruction
# cant findSkæbner
# cant findSømænd
# cant findKrige
# cant findStudenter
# cant findStudenter
# cant findKunst
# cant findForbindelsesled
# cant findDen lokale
# cant findHistorie
# cant findHvilken er min postkasse
# cant findGodt de alle er hvide
# cant findMinimalistisk bolig til leje
# cant findLæring
# cant findRod
# cant findAffald
# cant findTest
# cant find;)
# cant findInclusion
# cant findTravlt
# cant findStore rejsedag
# cant findDen vide verden
# cant findDecoration
# cant findMetal
# cant findConcrete
# cant findLiv og død
# cant findNye opfindelser
# cant findOmsorg
# cant findKamp
# cant findGrey
# cant findMetal
# cant findGrey
# cant findCozzy
# cant findGrey
# cant findColor
# cant findLeg
# cant findAgresive
# cant findKunst
# cant findHistorie
# cant findColor
# cant findFristed
# cant findPause
# cant findLiv
# cant findGlæde
# cant findFest
# cant findGrønne fingre
# cant findEftermiddagsbajer
# cant findNy gadeblægning
# cant findLake
# cant findStore kanonkugler
# cant findKaos
# cant findLærdom
# cant findMobning
# cant findSammenhold
# cant findLiv
# cant findPrøv at nå solen
# cant findRør ikke samme farve 2 gange
# cant findRør ikke samme farve 2 gange
# cant findHistorie
# cant findGrey
# cant findMagtens elite
# cant findSkjulte aftaler
# cant findNoget for noget
# cant findDemokrati
# cant findGrey
# cant findMagtens elite
# cant findNoget for noget
# cant findSkjulte aftaler
# cant findDemokrati
# cant findEt land for alle
# cant findHistorie
# cant findHistorie
# cant findKunst
# cant findStudenter
# cant findMetal
# cant findOmsorg
# cant findSammehold
# cant findHjælpsomhed
# cant findLiv/død
# cant findOplevelser
# cant findInclusion
# cant findMiljø
# cant findHome
# cant findIngen adgang for kørestole
# cant findAcces
# cant findDyrt boligbyggeri
# cant findFremtidens ghettobyggeri
# cant findFantasiløst
# cant findFred og ro
# cant findMasser af liv
# cant findGhettobyggeri
# cant findDyrt boligbyggeri
# cant findMetal
# cant findChaos
# cant findCold
# cant findLeg
# cant findFantasi
# cant find;)
# cant findNy hip idé i kommunen?
# cant findDark
# cant findDirty
# cant findGrey
# cant findMangler en kærlig hånd
# cant findEn pause på vejen
# cant findSkæbner
# cant findMenneskehistorier
# cant findAlkohol og stoffer
# cant findSammenhold
# cant findHjælpsomhed
# cant findFrivillighed
# cant findIkke for en kørestol
# cant findInaccessibility
# cant findKunst
# cant findOplevelser
# cant findKunst
# cant findOplevelser
# cant findKunst
# cant findOplevelser
# cant findSammenhold
# cant findFrivillighed
# cant findHjælpsomhed
# cant findNarkotika
# cant findBander
# cant findSammenhold
# cant findHkælpsomhed
# cant findNarkotika
# cant findBander
# cant findFarveløst
# cant findKedeligt
# cant findDyre boliger
# cant findDyre boliger
# cant findEkskluderende
# cant findFremtidens ghetto
# cant findFantasiløst byggeri
# cant findFarveløst
# cant findWater
# cant findDet evige byggeprojekt
# cant findMetal
# cant findLanguage
# cant findGrafitti
# cant findExpression
# cant findAgressivity
# cant findDeath
# cant findHygge
# cant findConcrete
# cant findGrey
# cant findLeg
# cant findFantasi
# cant findColors
# cant findFandens trapper
# cant findPlay
# cant findChildhood
# cant findUninteresting
# cant findHistorie
# cant findKunst
# cant findOplevelser
# cant findBoring
# cant findMetal
# cant findDirty
# cant findDestruction
# cant findcars
# cant findFarlig
# cant findIkke plads nok
# cant findElevator der aldrig virker
# cant findMin fortabte ungdom
# cant findTree-alley
# cant findLeisure
# cant findPlay
# cant findcolorful
# cant findTilgængelighed
# cant findHistorier
# cant findMetal
# cant findHygge
# cant findTilgængelighed
# cant findUnknown
# cant findUnwelcoming
# cant findLanguage
# cant findSøndagsaktivitet
# cant findSammenhold
# cant findAlle er ens
# cant findNyt byggesjusk?
# cant findDyre boliger
# cant finddiversity
# cant findØkologi
# cant findÅrstiderne
# cant findForbindelsesled
# cant findMetal
# cant findØkologi
# cant findLys på vejen
# cant findModer natur vinder altid til sidst
# cant findForbindelse
# cant findLøse høns
# cant findDestruction
# cant findHærværk
# cant findDestruction
# cant findLanguage
# cant findPersonaleboliger
# cant findIngen adgang
# cant findBag tremmer
# cant findMulighed for en samtale
# cant findTag en pause
# cant find;)
# cant findCar
# cant findUd og se med DSB
# cant findHistorier
# cant findMiljø
# cant findStigende priser
# cant find;)
# cant findExpense
# cant findBrosten, fandens opfindelse
# cant find3 bakker jordbær for 50,00
# cant findGrey
# cant findLanguage
# cant findModernity
# cant findInclusion
# cant findChristian d IV
# cant findForpustet
# cant findStejlt
# cant findIkonisk bænk
# cant findHistorie
# cant findHandicapvenlig
# cant findBare ikke toiletterne
# cant findLån en cykel, husk at stille den tilbage
# cant findMasser af penge
# cant findKunst
# cant findStreet art
# cant findGrey
# cant findBumletur for kørestole
# cant findDark
# cant findGrey
# cant findBus til tiden
# cant findIkke for kørestole
# cant findKunst
# cant findJulefrokost
# cant findMasser af turister
# cant findForbandede brosten!
# cant findGodt for miljøet
# cant findSpar på emballagen
# cant findKøb kun det du har brug for
# cant findUser experience
# cant findRyd op efter dig
# cant findSammenhørighed
# cant findFrivillighed
# cant findÅbent hus
# cant findRod
# cant findLandscape
# cant findWarmth
# cant findBumletur
# cant findNye nyrer
# cant findHjertet op i halsen
# cant findAltid god musik
# cant findDark
# cant findConcrete
# cant findGrey
# cant findDark
# cant findDarkness
# cant findDarkness
# cant findTexture
# cant findGrey
# cant findSeparation
# cant findKoldt
# cant findSterielt
# cant findModernity
# cant findIkke for kørestole
# cant findHimmel og helvede
# cant findHomorous
# cant findMetal
# cant findCold
# cant findHimmel og helvede
# cant findColor
# cant findHappiness
# cant findstreet
# cant findOplivende
# cant findGlæde
# cant findArt
# cant findFreaky
# cant findHumorous
# cant findHome
# cant findBarndomsminder
# cant findBudskab
# cant findKanalforurener
# cant findGrit
# cant findactive mobility
# cant findactive mobility
# cant findSmall shops
# cant findPersonal service
# cant findAgresivity
# cant findPoliti
# cant findPusherstreet
# cant findSolidaritet
# cant findEkskluderende/inkluderende
# cant findSocial bevidst
# cant findMetal
# cant findGrit
# cant findGrit
# cant findModer natur vinder altid
# cant findLike the UK
# cant findFest og farver
# cant findGod mad
# cant findAltid mange turister om sommeren
# cant findWalking
# cant findKunstig
# cant findIngen ramper
# cant findIngen kantsten i niveau
# cant findChill
# cant findoutdoor furniture
# cant findSolsikker højere end huset
# cant findHeritage
# cant findÅh nej, endnu en omvej
# cant findTilgængelighed
# cant findPå rad og række
# cant findForhindringsbane
# cant findGammelt og nyt
# cant findØkologi
# cant findSmå landbrug
# cant findNærhed
# cant findTrapper fandens opfindelse
# cant findTilgængelighed
# cant findDestruction
# cant findHelvedes for kørestole
# cant findObstrucle
# cant findTilgængelighed
# cant findHistorie
# cant findÅh, jeg er tørstig
# cant findMiljø
# cant findHjælp til hjemløse
# cant findSamtalebænk
# cant findForbedringer
# cant findInclusion
# cant findForfaldenhed
# cant findGode løberuter
# cant findMotion
# cant findHvad skal vi så have i aften?
# cant findMilitærhistorie
# cant findFortabte sjæle
# cant findHåb
# cant findHistorie
# cant findZen
# cant findOasis
# cant findMotion
# cant findFrihed
# cant findRo og fred
# cant findLiv
# cant findMasser af sjæl
# cant findMasser af historier
# cant findEt helvede for en kørestol
# cant findBygning
# cant findForbedring
# cant findEnsom Majestæt
# cant findSelfi
# cant findKunst for alle
# cant findAnimal
# cant findLæring
# cant findKreativitet
# cant findInclusion
# cant findHistorier
# cant findOasis
# cant findGemte perler
# cant findOasis
# cant findBørne
# cant findLege
# cant findKunst
# cant findFun
# cant findColor
# cant findPlayfulness
# cant findGlæde
# cant findSamtalebænk
# cant findImagination
# cant findVenter og venter og venter
# cant findSjæl
# cant findMasser af historier
# cant findMasser af sjæl
# cant findJulegaveged
# cant findOverforbrug
# cant findHumor
# cant findSkal, skal ikke
# cant findBus til tiden
# cant findInaccebility
# cant findOmsorg
# cant findDeling
# cant findInkluderende
# cant findInclusiveness
# cant findInclusion
# cant findAlle skal hjem
# cant findBilfri søndag
# cant findBodega
# cant findWaiting
# cant findEn "lånt" cykel
# cant findFald nu ikke over mig
# cant findLedelys
# cant findTilgænglighed
# cant findUniversal design
# cant findAccessibility
# cant findTag dit lort med dig
# cant findEn kold gade
# cant findEmpty
# cant findTraffic
# cant findDemographics
# cant findCivic participation
# cant findHomogenous
# cant findMismatch
# cant findTog til tiden
# cant findUd og se med DSB
# cant findDepresive
# cant findGraffiti
# cant findAgressivity
# cant findAlle har vel brug for en pause
# cant findEfteråret er på vej
# cant findRemember a black plastic back
# cant findMor og barn
# cant findEt uheld venter på at ske
# cant findBiking in all weather
# cant findFun
# cant findMarked for alle
# cant findManglende tilgængelighed
# cant findKunst
# cant findEdderkopperne kommer
# cant findDepressive
# cant findGrey
# cant findDark
# cant findRain
# cant findSpærret inde eller ude
# cant findMetal
# cant findAggressive
# cant findBoring
# cant findMisbrugt allerede
# cant findAffordability
# cant findModer natur vinder altid
# cant findGraffiti
# cant findFuglefoderbræt
# cant findExpense
# cant findNem adgang til transport
# cant findTilgængelighed
# cant findSten på sten
# cant findFarver
# cant findIntelligence
# cant findModernity
# cant findInclusivity
# cant findBumletur for kørestole
# cant findTilgængelighed
# cant findOvenlys
# cant findUdluftning
# cant findSport
# cant findChildhood
# cant findTro
# cant findSport
# cant findLeisure
# cant findIdeology
# cant findLanguage
# cant findMalplacerede træer
# cant findForhindringsløb for kørestole og rollatorer
# cant findOh dear
# cant findSjæl
# cant findHistorier
# cant findMalplaceret
# cant findEn potte med ukrudt
# cant findTerrorism
# cant findIdiots
# cant findTro
# cant findMin kørestol kan ikke være her
# cant findBumletur
# cant findTilgængelighed
# cant findAccessibility
# cant findSmart design
# cant findObstrucle
# cant findKunst
# cant findCold
# cant findLys
# cant findObstrucle
# cant findTrapper er ikke godt for kørestole
# cant findHvad hvis jeg vil op Ad trappen?
# cant findObstrucle
# cant findNy form for bilreklame
# cant findHomorous
# cant findEndelig kaffepause
# cant findHvir bliver du af?
# cant findUtrygt
# cant findcars
# cant findTro
# cant findMagt
# cant findMisbrug
# cant findKor
# cant findLukket for idag
# cant findHygge med en ven
# cant findAlene i verden
# cant findEndelig levende musik
# cant findGrøn koncert
# cant findKunst
# cant findFest
# cant findDarkness
# cant findHjerte
# cant findGlæde
# cant findVenlighed
# cant findWelfare art
# cant findUd & se med DSB, bare ikke når du er handiccappet
# cant findEn start på en hyggelig aften
# cant findCozy
# cant findExpensive
# cant findHygge
# cant findMin barndom
# cant findKunst
# cant findDark
# cant findJulelys
# cant findDark
# cant findUtryg
# cant findDarkness
# cant findAgresiviness
# cant findAccessibility
# cant finddarkness
# cant findemptiness
# cant findLanguage
# cant findDark

# %% [markdown]
# # Create Unique code for each photo

# %%
from operator import itemgetter
sorted_list = sorted(dataList, key=itemgetter('userOrg', 'userId'))


# Codelist to create unique id for each user to enable link back to specific organisation in later phase (if needed)
codeList = {
        'DDL': 'A',
        'DHF': 'B',
        'ENG': 'C',
        'HUGS': 'D',
        'LGBTQ': 'E',
        'MINO': 'F',
        'SIND':  'G',
        }

previousOrg = sorted_list[0]['userOrg']
previousUser = sorted_list[0]['userId'] 
photoNr = 0
userCode = 1
for item in sorted_list:
    currentOrg = item['userOrg']
    orgCode = codeList[currentOrg]
    currentUser = item['userId']
    if currentOrg == previousOrg:
        if currentUser == previousUser:
            photoNr += 1
            item['uniqueCode'] = orgCode + str(userCode) + '-' + str(photoNr)
        else:
            userCode += 1
            photoNr = 1
            item['uniqueCode'] = orgCode + str(userCode) + '-' + str(photoNr)
    else:
        userCode = 1
        photoNr = 1
        item['uniqueCode'] = orgCode + str(userCode) + '-' + str(photoNr)
    previousUser = currentUser
    previousOrg = currentOrg

# %% [markdown]
# # Write result to CSV

# %%
with open('dataoutput_test2.csv', 'w', encoding='utf8', newline='') as output_file:
    fc = csv.DictWriter(output_file, 
                        fieldnames=sorted_list[0].keys(),
                       )
    fc.writeheader()
    fc.writerows(sorted_list)
